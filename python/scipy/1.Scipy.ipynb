# %% [markdown]
# # SciPy Tutorial -> Scientific Python
#  - uses NumPy underneath
#  - It provides more utility fun for optimization, stats, single processing

# %%
pip install scipy
# Out:
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB 1.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.2/44.5 MB 3.9 MB/s eta 0:00:12
#    ---------------------------------------- 0.5/44.5 MB 6.3 MB/s eta 0:00:07
#    - -------------------------------------- 1.3/44.5 MB 10.6 MB/s eta 0:00:05
#    -- ------------------------------------- 2.7/44.5 MB 15.4 MB/s eta 0:00:03
#    --- ------------------------------------ 4.0/44.5 MB 18.3 MB/s eta 0:00:03
#    ---- ----------------------------------- 5.1/44.5 MB 19.3 MB/s eta 0:00:03
#    ----- ---------------------------------- 6.5/44.5 MB 20.8 MB/s eta 0:00:02
#    ------- -------------------------------- 8.2/44.5 MB 22.7 MB/s eta 0:00:02
#    -------- ------------------------------- 9.8/44.5 MB 24.1 MB/s eta 0:00:02
# ...

# %%
from scipy import constants
print(constants.liter)
# Out:
# 0.001

# %%
import scipy
print(scipy.__version__)
# Out:
# 1.14.0
